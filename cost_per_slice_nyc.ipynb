# %% [markdown]
# <a href="https://colab.research.google.com/github/rogerfvieira/pizza_slice_nyc/blob/main/cost_per_slice_nyc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.cloud import bigquery 
from google.colab import auth
auth.authenticate_user()

# %%
project_id = 'play-368717'
dataset_id = 'mm_monday'
client = bigquery.Client(project=project_id)

# %%
data_query = """
SELECT 
  Name AS name,
  CONCAT(location_lat,",",location_lng) AS location,
  Date_Expanded__times_in_EST_ AS day,
  Price AS price,
  Style AS type
FROM `play-368717.mm_monday.mm_pizza`
"""

df = client.query(data_query).to_dataframe()

# %%
df
# Out:
#                                 name                        location  \
# 0                        N & D Pizza  40.6004632,-73.943072399999991
# 1                    Enzo's Pizzeria          40.6842128,-73.8593422
# 2                          iPizza NY          40.7608035,-73.9906251
# 3                Austin Street Pizza          40.7195744,-73.8426559
# 4                     Marinara Pizza          40.7297781,-73.9865052
# ..                               ...                             ...
# 459  Antonio's Pizzeria & Restaurant          40.6769775,-73.9725052
# 460                     Hank's Pizza  40.7094362,-74.012025299999991
# 461                     Hank's Pizza  40.7094362,-74.012025299999991
# 462         Carmine's Original Pizza        40.72555137,-73.95147023
# 463         Carmine's Original Pizza        40.72555137,-73.95147023
#
#                             day  price       type
# 0      Sep 5th 2022, 4:37:08 pm   3.35      Plain
# ...

# %% [markdown]
# # Data Visualization

# %% [markdown]
# https://lookerstudio.google.com/reporting/0a3eb321-3abd-4c80-8e3d-52300409c403
